# %%
import pandas as pd

# %%
tick1 = pd.read_csv("../data/Tickers.csv")

# %%
tick2 = pd.read_csv("../data/top_companies.csv")

# %%
df = pd.merge(tick1, tick2, right_on="Symbol", left_on="Ticker", how="left")

# %%
df
# Out:
#    Ticker Symbol                                               Name Last Sale  \
# 0    AAPL   AAPL                            Apple Inc. Common Stock   $191.24
# 1    MSFT   MSFT                 Microsoft Corporation Common Stock   $374.51
# 2    GOOG   GOOG                Alphabet Inc. Class C Capital Stock   $133.32
# 3    AMZN   AMZN                       Amazon.com Inc. Common Stock   $147.03
# 4    NVDA   NVDA                    NVIDIA Corporation Common Stock   $467.65
# 5    META   META           Meta Platforms Inc. Class A Common Stock   $324.82
# 6    TSLA   TSLA                            Tesla Inc. Common Stock   $238.83
# 7     LLY    LLY                 Eli Lilly and Company Common Stock   $584.04
# 8       V      V                                          Visa Inc.   $256.45
# 9     UNH    UNH  UnitedHealth Group Incorporated Common Stock (DE)   $547.16
# 10    JPM    JPM                 JP Morgan Chase & Co. Common Stock   $156.84
# ...

# %%
df2 = df[["Ticker", "Name", "Sector", "Industry", "Country"]]

# %%
df2
# Out:
#    Ticker                                               Name  \
# 0    AAPL                            Apple Inc. Common Stock
# 1    MSFT                 Microsoft Corporation Common Stock
# 2    GOOG                Alphabet Inc. Class C Capital Stock
# 3    AMZN                       Amazon.com Inc. Common Stock
# 4    NVDA                    NVIDIA Corporation Common Stock
# 5    META           Meta Platforms Inc. Class A Common Stock
# 6    TSLA                            Tesla Inc. Common Stock
# 7     LLY                 Eli Lilly and Company Common Stock
# 8       V                                          Visa Inc.
# 9     UNH  UnitedHealth Group Incorporated Common Stock (DE)
# 10    JPM                 JP Morgan Chase & Co. Common Stock
# 11   AVGO                         Broadcom Inc. Common Stock
# 12    WMT                          Walmart Inc. Common Stock
# 13    XOM               Exxon Mobil Corporation Common Stock
# ...

# %%
df2.to_csv("../data/Tickers_Full.csv", index=False)
